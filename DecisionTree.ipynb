# %%
#Import the Necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the data sets- train and test 
df=pd.read_csv('train_titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Look at top values of train data 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Print the column names of train data
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Print the dimension of train and test data
df.shape
# Out:
# (891, 12)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Barchart of Survived, Pclass, Sex, Embarked
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.countplot(x=df['Survived'])
plt.subplot(2,2,2)
sns.countplot(x=df['Parch'])
plt.subplot(2,2,3)
sns.countplot(x=df['Sex'])
plt.subplot(2,2,4)
sns.countplot(x=df['Embarked'])
plt.show()

# %%
#Histogram of Age, Parch, Fare
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.title("1")
sns.histplot(df['Age'],kde=True)
plt.subplot(1,3,2)
plt.title("2")
sns.histplot(df['Parch'],kde=True)
plt.subplot(1,3,3)
plt.title("3")
sns.histplot(df['Fare'],kde=True)
plt.show()
# Out:
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(x=df['Age'],hue=df['Survived'],kde=True)
# Out:
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#Count class and geder wise survival rate - plot with appropriate chart
# df.groupby(df['Sex']).size()
sns.barplot(x=df['Pclass'],y=df['Survived'],hue=df['Sex'])
plt.show()

# %%
#Age wise Distribution of Male and Female passengers
g = sns.FacetGrid(df,col="Sex",height=5)
g.map_dataframe(sns.histplot, x="Age", bins=20, kde=True, color="skyblue")
# Out:
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# sns.blend_palette(colors=['red','blue','yellow'], n_colors=6, as_cmap=False, input='rgb')
a=sns.FacetGrid(df,col='Sex')
a.map_dataframe(sns.histplot,x='Age',kde=True)
# Out:
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked'].fillna('S',inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data
age_mean=df['Age'].mean();
age_std=df['Age'].std()

ramdom_values=np.random.normal(age_mean,age_std,177)
ramdom_values
# Out:
# array([12.95558842,  8.61416999,  3.41679585, 49.9689694 , 11.58659378,
#        21.48527065, 27.74049036, 33.341588  , 13.81894775, 32.94108595,
#         9.80147539, 37.90604812, 26.31021088, 23.74462201, 62.69106884,
#        35.44497474, 74.24447195, 30.31558047, 42.21840351,  7.14988475,
#        73.76391621, 34.96317077, 47.17641144, 26.21061294, 34.91175777,
#        26.37289789, 37.94934738, 35.96428353, 54.52692526, 31.00416519,
#        39.04935523, 27.96553739, 26.19615035, 23.30089687, 36.30593709,
#        32.49160091, 19.69903679, 31.5549576 , 27.39301363, 24.43813147,
#        50.4659828 , 34.97106019, 40.10831532, 52.86726999, 36.66918653,
#        11.6971585 , 19.89561741, 83.32126559, 28.24269808, 23.55986701,
#         5.09241881, 39.41301828, 26.54649203, -4.95832663, 40.13100095,
#        26.34126972, 22.87066475, 10.21700817, 27.68854824,  3.47135426,
#        50.65292444, 18.25284656, 22.38148829, 31.00150112, 31.50019505,
#        42.17134602, 37.34593978, 34.59262658, 70.74849232, 33.63477982,
#        48.37686562, 33.08301144, 22.4472644 ,  3.81935063, 43.99941874,
#        18.55544635, 33.70350458, 39.50407042, 48.24507096, 13.41299593,
#        30.46392533, 59.67647436, 45.77348916, 40.38182456, 46.09167166,
#        35.81366505, 35.45005267, 24.5505332 , 49.0423909 , 18.03965481,
#        21.82510344, 18.7425697 , 37.24856178, 24.15493772, 23.76380107,
#        15.25403867, 32.70845835, 47.19012977, 24.98883357,  6.50514923,
#        41.35104901, 30.93617396, 14.30391092, 38.40291362, 18.81005699,
#        57.67326565, 44.61144616, 10.87795335, 25.32237529, -2.02744305,
#         0.19246627,  5.68819039, 19.41966384, 48.35953934, 40.40530775,
#        43.9636118 , 26.9312515 , 41.22278455, 28.67139989, 27.38126542,
#        16.53629951, 22.46536477, -5.57786428, 38.47680892, 44.0031726 ,
#        46.87591922,  0.18113343, 29.43536561, -0.28642847, 14.85541479,
#        26.44743171, 46.22467991, 25.60796242, 18.13526393, 26.7852995 ,
#        33.33417389, 22.88946124,  7.83469876, -4.47598947, 22.44684039,
#        43.71251783, 37.03596437, 25.22923156, 10.21737434, 20.64115325,
#        23.37602973, 38.26199565, 38.75067926, 22.53405231, 27.42333172,
#        18.01364083, 19.51413863, 29.86019308, -2.86683487, 30.91731881,
#        62.72608675, 26.19106707, 49.97414839, 10.13421939, 49.62661988,
#        22.64393533,  7.64820433, 17.88152836, 28.31653317, 30.39693388,
#        41.15650824, 23.54196314, 47.96508142, 53.80359321, 29.44584991,
#        44.74099194, 28.28268138, 35.5694914 , 28.61670145, 46.52363687,
#        30.19952743, 38.99378102])

# %%
df.loc[df['Age'].isna(),"Age"]=ramdom_values

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df['FamilySize']=df['Parch']+df['SibSp']+1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# 3      0            113803  53.1000  C123        S           2
# 4      0            373450   8.0500   NaN        S           1

# %%
df['IsAlone']=df['FamilySize']==1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  IsAlone
# 0      0         A/5 21171   7.2500   NaN        S           2    False
# 1      0          PC 17599  71.2833   C85        C           2    False
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1     True
# 3      0            113803  53.1000  C123        S           2    False
# 4      0            373450   8.0500   NaN        S           1     True

# %%
df1=df.drop(columns=['PassengerId','Name','Ticket','Cabin'])

# %%
df1
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  38.993781      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#      FamilySize  IsAlone
# 0             2    False
# 1             2    False
# 2             1     True
# 3             2    False
# 4             1     True
# ..          ...      ...
# 886           1     True
# 887           1     True
# 888           4    False
# 889           1     True
# 890           1     True
#
# [891 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X=df1.drop(columns=['Survived'])
y=df1['Survived'];

# %%
X
# Out:
#      Pclass     Sex        Age  SibSp  Parch     Fare Embarked  FamilySize  \
# 0         3    male  22.000000      1      0   7.2500        S           2
# 1         1  female  38.000000      1      0  71.2833        C           2
# 2         3  female  26.000000      0      0   7.9250        S           1
# 3         1  female  35.000000      1      0  53.1000        S           2
# 4         3    male  35.000000      0      0   8.0500        S           1
# ..      ...     ...        ...    ...    ...      ...      ...         ...
# 886       2    male  27.000000      0      0  13.0000        S           1
# 887       1  female  19.000000      0      0  30.0000        S           1
# 888       3  female  38.993781      1      2  23.4500        S           4
# 889       1    male  26.000000      0      0  30.0000        C           1
# 890       3    male  32.000000      0      0   7.7500        Q           1
#
#      IsAlone
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
# ..       ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
#
# [891 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
# Label encoding of categorical features
X['Sex']=le.fit_transform(X['Sex'])
X['Embarked']=le.fit_transform(X['Embarked'])
X['IsAlone']=le.fit_transform(X['IsAlone'])
X
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked  FamilySize  \
# 0         3    1  22.000000      1      0   7.2500         2           2
# 1         1    0  38.000000      1      0  71.2833         0           2
# 2         3    0  26.000000      0      0   7.9250         2           1
# 3         1    0  35.000000      1      0  53.1000         2           2
# 4         3    1  35.000000      0      0   8.0500         2           1
# ..      ...  ...        ...    ...    ...      ...       ...         ...
# 886       2    1  27.000000      0      0  13.0000         2           1
# 887       1    0  19.000000      0      0  30.0000         2           1
# 888       3    0  38.993781      1      2  23.4500         2           4
# 889       1    1  26.000000      0      0  30.0000         0           1
# 890       3    1  32.000000      0      0   7.7500         1           1
#
#      IsAlone
# 0          0
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# 886        1
# 887        1
# 888        0
# 889        1
# 890        1
#
# [891 rows x 9 columns]

# %%
sns.pairplot(X)
# Out:
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
X
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked  FamilySize  \
# 0         3    1  22.000000      1      0   7.2500         2           2
# 1         1    0  38.000000      1      0  71.2833         0           2
# 2         3    0  26.000000      0      0   7.9250         2           1
# 3         1    0  35.000000      1      0  53.1000         2           2
# 4         3    1  35.000000      0      0   8.0500         2           1
# ..      ...  ...        ...    ...    ...      ...       ...         ...
# 886       2    1  27.000000      0      0  13.0000         2           1
# 887       1    0  19.000000      0      0  30.0000         2           1
# 888       3    0  38.993781      1      2  23.4500         2           4
# 889       1    1  26.000000      0      0  30.0000         0           1
# 890       3    1  32.000000      0      0   7.7500         1           1
#
#      IsAlone
# 0          0
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# 886        1
# 887        1
# 888        0
# 889        1
# 890        1
#
# [891 rows x 9 columns]

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((712, 9), (179, 9), (712,), (179,))

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier(criterion='entropy')

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred=dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7821229050279329

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt,filled=True)
plt.show()

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(dt,filled=True,max_depth=3,feature_names=X.columns)
plt.show()

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score,classification_report

sns.heatmap(confusion_matrix(y_pred,y_test),cmap="winter")
confusion_matrix(y_pred,y_test)
# Out:
# array([[94, 18],
#        [21, 46]])

# %%
# plt.colormaps()

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7821229050279329

# %%
precision_score(y_pred,y_test)
# Out:
# 0.71875

# %%
recall_score(y_pred,y_test)
# Out:
# 0.6865671641791045

# %%
f1_score(y_pred,y_test)
# Out:
# 0.7022900763358778

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       112
#            1       0.72      0.69      0.70        67
#
#     accuracy                           0.78       179
#    macro avg       0.77      0.76      0.77       179
# weighted avg       0.78      0.78      0.78       179
